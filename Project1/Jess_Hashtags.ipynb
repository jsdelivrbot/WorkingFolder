# %%
#Dependencies 
import tweepy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)


# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Hashtags
target_tags = ["#NoPainNoGain", "#Cardio", "#Cycling", "#FitFam", "#FitLife", "#Fitness"]
#"#FitnessAddict","#GymLife", "#GymTime","#Sweat","#Workout","#Marathon", "#Runners", "#bodybuilding",
#"#beachbody", "#Motivation", "#justdoit"]

hastags = []
hashtags_count = []
users = []
tweet= []

# User Filters
min_tweets = 5
max_tweets = 10000
max_followers = 150
max_following = 100
lang = "en"

#Loop through tager users 
for target_tag in target_tags:
    
    counter = 0 
    
    # Loop through 5 pages of tweets (100  tweets)
    for x in range(5):
       
    # Get all tweets from tager user home feed
        public_tweets = api.search(target_tag, count = 50)
        pprint(target_tag)

        # For each target tag, loop through all tweets 
        for tweet in public_tweets["statuses"]:
            #pprint(tweet)
            counter +=1 
            print(tweet["user"]["screen_name"])
            users.append(tweet["user"]["screen_name"])
            tweet.append(tweet["text"])
            hashtags.append(target_tags)
# Out:
# '#NoPainNoGain'
# fabiolsaito
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-363eaf9c4f37> in <module>()
#      34             print(tweet["user"]["screen_name"])
#      35             users.append(tweet["user"]["screen_name"])
# ---> 36             tweet.append(tweet["text"])
#      37             hashtags.append(target_tags)
#      38
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
data = pd.DataFrame ({"Hashtag": target_tag,
                    "User": users})
Unique_Data = data.drop_duplicates
Unique_Data = pd.DataFrame ({"Hashtag": target_tag,
                    "User": users})
Unique_Data
# Out:
#          Hashtag         User
# 0  #NoPainNoGain  fabiolsaito

# %%
Unique_Data.to_csv("Hashtags.csv")

# %%
# Target Hashtags
target_tags = ["#NoPainNoGain","#Cardio", "#Cycling", "#FitFam", "#FitLife", "#Fitness"]
#"#FitnessAddict","#GymLife", "#GymTime","#Sweat","#Workout","#Marathon", "#Runners", "#bodybuilding",
#"#beachbody", "#Motivation", "#justdoit"]

hashtags = []
hashtags_count = []
users = []
tweet= []

# User Filters
min_tweets = 30
max_tweets = 5000
max_followers = 150
max_following = 100
lang = "en"

#Loop through tager users 
for target_tag in target_tags:
    
    counter = 0 
    
    # Loop through 5 pages of tweets (100  tweets)
    for x in range(10):
       
    # Get all tweets from tager user home feed
        public_tweets = api.search(target_tag)
        #print(target_tag)

            # Print Tweets
        for tweet in public_tweets["statuses"]:

            # Use filters to check if user meets conditions
            if (tweet["user"]["followers_count"] < max_followers and
            tweet["user"]["statuses_count"] > min_tweets and
            tweet["user"]["statuses_count"] < max_tweets and
            tweet["user"]["friends_count"] < max_following and
            tweet["user"]["lang"] == lang):

            # If so, add the user's tweet and username to the array (for future use)
            #tweet.append(tweet["text"])
            #users.append(tweet["user"["screen_name"]])
            #Print username               
                print(target_tag)
                print(tweet["user"]["screen_name"])
                counter +=1
# Out:
# #NoPainNoGain
# goonie_ryan
# #NoPainNoGain
# goonie_ryan
# #NoPainNoGain
# goonie_ryan
# #NoPainNoGain
# goonie_ryan
# #NoPainNoGain
# goonie_ryan
# #NoPainNoGain
# goonie_ryan
# #NoPainNoGain
# goonie_ryan
# #NoPainNoGain
# goonie_ryan
# #NoPainNoGain
# goonie_ryan
# #NoPainNoGain
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #Cardio
# 100_Weight_Loss
# #Cardio
# goonie_ryan
# #FitFam
# cricketGainz
# #FitFam
# 100_Weight_Loss
# #FitFam
# cricketGainz
# #FitFam
# 100_Weight_Loss
# #FitFam
# cricketGainz
# #FitFam
# 100_Weight_Loss
# #FitFam
# ...

# %%
# Print total number of "Real" tweets
print(len(users))
